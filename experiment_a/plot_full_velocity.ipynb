# %% [markdown]
# ## Setup Colab

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
wdir = '/content/gdrive/Othercomputers/My MacBook Air/cell-jamming/experiment_a'

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import matplotlib.image as mpimg
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %% [markdown]
# ## Full velocity video (vector for each nucleus)

# %%
video_name = 'full_velocity'

data_folder_name = 'data_extracted'
videos_dir = 'videos/' + video_name
n_frames = 29

# %%
for i in range(0, n_frames):
  number_str = str(i).zfill(3)
  
  file_name =  'frame' + number_str + '.csv'
  img_name =  'frame' + number_str + '.png'

  df = pd.read_csv(os.path.join(wdir, data_folder_name, file_name))
  X = df['pos_x'].to_numpy()
  Y = df['pos_y'].to_numpy()
  U = df['vel_x'].to_numpy()
  V = df['vel_y'].to_numpy()

  fig, ax = plt.subplots(1, 1, figsize=(6,6))
  fig.suptitle('Frame ' + number_str)
  ax.quiver(X, Y, U, V, edgecolors='k')
  ax.set_ylim(ax.get_ylim()[1], ax.get_ylim()[0])
  fig.savefig(os.path.join(wdir, videos_dir, img_name))
  plt.close(fig)

# %%
# %cd {os.path.join(wdir, videos_dir)}
# !ffmpeg -r 6 -i frame%03d.png -vcodec mpeg4 -y {video_name}.mp4
# Out:
# /content/gdrive/Othercomputers/My MacBook Air/cell-jamming/experiment_a/videos/full_velocity
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'frame%03d.png':
#   Duration: 00:00:01.16, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 432x432 [SAR 2834:2834 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'full_velocity.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 432x432 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 6 fps, 12288 tbn, 6 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   29 fps=0.0 q=31.0 Lsize=     801kB time=00:00:04.66 bitrate=1405.2kbits/s speed=24.7x
# video:800kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.122261%

# %% [markdown]
# ## Full velocity merged video (vectors drawn on image)

# %%
video_name = 'full_velocity_merged'
data_folder_name = 'data_extracted'
videos_dir = 'videos/' + video_name

nuclei_folder_name = 'nuclei'
nuclei_dir = 'videos/' + nuclei_folder_name

n_frames = 29

# %%
for i in range(0, n_frames):

  number_str = str(i).zfill(3)
  
  file_name =  'frame' + number_str + '.csv'
  img_name =  'frame' + number_str + '.png'

  # Image for background.
  img = mpimg.imread(os.path.join(wdir, nuclei_dir, img_name))

  # Data for velocities.
  data = pd.read_csv(os.path.join(wdir, data_folder_name, file_name))
  df = pd.DataFrame(data, columns=['pos_x','pos_y','vel_x','vel_y']) 

  x = df['pos_x'].to_numpy() 
  y = df['pos_y'].to_numpy() 
  vx = df['vel_x'].to_numpy() 
  vy = df['vel_y'].to_numpy()
  
  xmin = np.min(x) ; xmax = np.max(x) 
  ymin = np.min(y) ; ymax = np.max(y) 
  Lx = xmax - xmin 
  Ly = ymax - ymin 
  xyFigSizeRatio = Lx / Ly 
  yFigSize = 10

  fig, ax = plt.subplots( figsize = ( int( xyFigSizeRatio * yFigSize ) + 1 , yFigSize ) ) 

  imgplot = plt.imshow(img)
  ax.quiver(x, y, vx, vy, width = 0.005, color='green') 
  
  ax.set_xlabel('X') 
  ax.set_ylabel('Y') 

  fig.savefig(os.path.join(wdir, videos_dir, img_name))
  plt.close(fig)

# %%
# %cd {os.path.join(wdir, videos_dir)}
# !ffmpeg -r 6 -i frame%03d.png -vcodec mpeg4 -y {video_name}.mp4
# Out:
# /content/gdrive/Othercomputers/My MacBook Air/cell-jamming/experiment_a/videos/full_velocity_merged
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'frame%03d.png':
#   Duration: 00:00:01.16, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 792x720 [SAR 2834:2834 DAR 11:10], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'full_velocity_merged.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 792x720 [SAR 1:1 DAR 11:10], q=2-31, 200 kb/s, 6 fps, 12288 tbn, 6 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   29 fps=0.0 q=31.0 Lsize=    1466kB time=00:00:04.66 bitrate=2573.7kbits/s speed=8.22x
# video:1465kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.067786%

# %% [markdown]
# ## Only nuclei video

# %%
video_name = 'nuclei'
videos_dir = 'videos/' + video_name

# %%
# %cd {os.path.join(wdir, videos_dir)}
# !ffmpeg -r 6 -i frame%03d.png -vcodec mpeg4 -y {video_name}.mp4
# Out:
# /content/gdrive/Othercomputers/My MacBook Air/cell-jamming/experiment_a/videos/nuclei
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'frame%03d.png':
#   Duration: 00:00:01.16, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1134x1134, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> mpeg4 (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'nuclei.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: mpeg4 (mp4v / 0x7634706D), yuv420p, 1134x1134, q=2-31, 200 kb/s, 6 fps, 12288 tbn, 6 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 mpeg4
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   29 fps=4.7 q=31.0 Lsize=    5261kB time=00:00:04.66 bitrate=9235.7kbits/s speed=0.757x
# video:5260kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019623%
